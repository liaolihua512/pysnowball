# %%
from pysnowball.finance import (cash_flow, indicator, balance, income, business)

from pysnowball.report import (report, earningforecast)

from pysnowball.capital import(
    margin, blocktrans, capital_assort, capital_flow, capital_history)

from pysnowball.realtime import(quotec, pankou)

from pysnowball.f10 import(skholderchg, skholder, main_indicator,
                           industry, holders, bonus, org_holding_change, 
                           industry_compare, business_analysis, shareschg, top_holders)

from pysnowball.token import (get_token,set_token)

# %%
import pysnowball as ball
import pandas as pd
token = "xq_a_token=b3669dba2f5aa440bdee32d6b891a46d5b2e6a6f;"
ball.set_token(token)
# Out:
# 'xq_a_token=b3669dba2f5aa440bdee32d6b891a46d5b2e6a6f;'

# %%
dic = ball.report('SZ002027')
data = pd.DataFrame(dic['list'])

# %%
data

# %%
dic = ball.indicator('SZ002027')

# %%
# Out:
# [{'report_date': 1569772800000,
#   'report_name': '2019三季报',
#   'avg_roe': [9.9, -0.7484756097560976],
#   'np_per_share': [0.9178, -0.004231311706629071],
#   'operate_cash_flow_ps': [0.142, 0.3358419567262463],
#   'basic_eps': [0.094, -0.7131522734208117],
#   'capital_reserve': [0.0223, 0.7559055118110237],
#   'undistri_profit_ps': [0.9618, 0.06370272063702719],
#   'net_interest_of_total_assets': [7.2395, -0.7426879591684409],
#   'gross_selling_rate': [44.0507, -0.3637987758556446]},
#  {'report_date': 1561824000000,
#   'report_name': '2019中报',
#   'avg_roe': [5.58, -0.8024079320113313],
#   'np_per_share': [0.8721, 0.02600000000000001],
#   'operate_cash_flow_ps': [0.0734, -0.1364705882352941],
#   'basic_eps': [0.05, -0.7826086956521738],
#   'capital_reserve': [0.0191, 0.5039370078740157],
#   'undistri_profit_ps': [0.9221, 0.14603529704200852],
#   'net_interest_of_total_assets': [4.0687, -0.7985772136357786],
#   'gross_selling_rate': [42.0125, -0.41499234842714566]},
#  {'report_date': 1553961600000,
#   'report_name': '2019一季报',
#   'avg_roe': [2.42, -0.78],
#   'np_per_share': [0.9604, 0.014900137377153124],
#   'operate_cash_flow_ps': [0.0396, -0.29159212880143104],
#   'basic_eps': [0.02, -0.7973657548125632],
#   'capital_reserve': [0.0127, -0.16447368421052636],
#   'undistri_profit_ps': [0.9907, 0.11239613743543687],
#   'net_interest_of_total_assets': [1.7824, -0.767780600612338],
#   'gross_selling_rate': [36.5417, -0.4699461557653366]},
#  {'report_date': 1546185600000,
#   'report_name': '2018年报',
#   'avg_roe': [46.92, -0.30643015521064304],
#   'np_per_share': [0.9675, 0.1409198113207548],
#   'operate_cash_flow_ps': [0.2577, -0.2416127133608005],
#   'basic_eps': [0.4, -0.18367346938775503],
#   'capital_reserve': [0.0127, -0.16447368421052636],
#   'undistri_profit_ps': [0.9702, 0.22515469124889492],
#   'net_interest_of_total_assets': [33.5042, -0.22362570009755603],
#   'gross_selling_rate': [66.2127, -0.08954316758955348]},
#  {'report_date': 1538236800000,
#   'report_name': '2018三季报',
#   'avg_roe': [39.36, -0.1621966794380587],
#   'np_per_share': [0.9217, 0.3588382721509656],
#   'operate_cash_flow_ps': [0.1063, -0.45543032786885246],
#   'basic_eps': [0.3277, 0.024062499999999952],
#   'capital_reserve': [0.0127, -0.15333333333333335],
#   'undistri_profit_ps': [0.9042, 0.4481101857783473],
#   'net_interest_of_total_assets': [28.1351, -0.10744276201624894],
#   'gross_selling_rate': [69.2402, -0.042102277836574074]},
#  {'report_date': 1530288000000,
#   'report_name': '2018中报',
#   'avg_roe': [28.24, -0.03650631183896282],
#   'np_per_share': [0.85, 0.07336784947594384],
#   'operate_cash_flow_ps': [0.085, -0.5940783190066857],
#   'basic_eps': [0.23, -0.20689655172413784],
#   'capital_reserve': [0.0127, -0.3923444976076555],
#   'undistri_profit_ps': [0.8046, 0.12405699916177702],
#   'net_interest_of_total_assets': [20.1998, 0.06631263329039885],
#   'gross_selling_rate': [71.8153, 0.014222928982801345]},
#  {'report_date': 1522425600000,
#   'report_name': '2018一季报',
#   'avg_roe': [11.0, -0.15123456790123463],
#   'np_per_share': [0.9463, -0.0879915188897456],
#   'operate_cash_flow_ps': [0.0559, -0.4866850321395776],
#   'basic_eps': [0.0987, -0.22099447513812162],
#   'capital_reserve': [0.0152, -0.1363636363636364],
#   'undistri_profit_ps': [0.8906, -0.07287112221528218],
#   'net_interest_of_total_assets': [7.6755, -0.12957439811297208],
#   'gross_selling_rate': [68.9396, 0.019834671621389754]},
#  {'report_date': 1514649600000,
#   'report_name': '2017年报',
#   'avg_roe': [67.65, -0.04354587869362361],
#   'np_per_share': [0.848, -0.0728187185654931],
#   'operate_cash_flow_ps': [0.3398, -0.3815070986530761],
#   'basic_eps': [0.49, -0.057692307692307744],
#   'capital_reserve': [0.0152, -0.27272727272727265],
#   'undistri_profit_ps': [0.7919, -0.05036575128912331],
#   'net_interest_of_total_assets': [43.1547, 0.19488153548397802],
#   'gross_selling_rate': [72.7247, 0.03244935334118891]},
#  {'report_date': 1506700800000,
#   'report_name': '2017三季报',
#   'avg_roe': [46.98, -0.13289036544850505],
#   'np_per_share': [0.6783, -0.11077608809648665],
#   'operate_cash_flow_ps': [0.1952, -0.42333825701624817],
#   'basic_eps': [0.32, -0.13513513513513511],
#   'capital_reserve': [0.015, -0.23857868020304568],
#   'undistri_profit_ps': [0.6244, -0.09989909182643798],
#   'net_interest_of_total_assets': [31.5219, 0.1289674438594606],
#   'gross_selling_rate': [72.2835, 0.0312719355814392]},
#  {'report_date': 1498752000000,
#   'report_name': '2017中报',
#   'avg_roe': [29.31, -0.14498249708284722],
#   'np_per_share': [0.7919, 0.27746410711405073],
#   'operate_cash_flow_ps': [0.2094, 0.09633507853403141],
#   'basic_eps': [0.29, -0.3555555555555556],
#   'capital_reserve': [0.0209, 0.060913705583756333],
#   'undistri_profit_ps': [0.7158, 0.29885683179096345],
#   'net_interest_of_total_assets': [18.9436, 0.06507292170334299],
#   'gross_selling_rate': [70.8082, 0.018657398149653275]}]

# %%
data = pd.DataFrame(dic["data"]["list"])
data
# Out:
#      report_date report_name                        avg_roe  \
# 0  1569772800000     2019三季报     [9.9, -0.7484756097560976]
# 1  1561824000000      2019中报    [5.58, -0.8024079320113313]
# 2  1553961600000     2019一季报                  [2.42, -0.78]
# 3  1546185600000      2018年报  [46.92, -0.30643015521064304]
# 4  1538236800000     2018三季报   [39.36, -0.1621966794380587]
# 5  1530288000000      2018中报  [28.24, -0.03650631183896282]
# 6  1522425600000     2018一季报   [11.0, -0.15123456790123463]
# 7  1514649600000      2017年报  [67.65, -0.04354587869362361]
# 8  1506700800000     2017三季报  [46.98, -0.13289036544850505]
# 9  1498752000000      2017中报  [29.31, -0.14498249708284722]
#
#                       np_per_share            operate_cash_flow_ps  \
# 0  [0.9178, -0.004231311706629071]     [0.142, 0.3358419567262463]
# 1    [0.8721, 0.02600000000000001]   [0.0734, -0.1364705882352941]
# 2   [0.9604, 0.014900137377153124]  [0.0396, -0.29159212880143104]
# 3     [0.9675, 0.1409198113207548]   [0.2577, -0.2416127133608005]
# 4     [0.9217, 0.3588382721509656]  [0.1063, -0.45543032786885246]
# 5      [0.85, 0.07336784947594384]    [0.085, -0.5940783190066857]
# 6    [0.9463, -0.0879915188897456]   [0.0559, -0.4866850321395776]
# 7     [0.848, -0.0728187185654931]   [0.3398, -0.3815070986530761]
# 8   [0.6783, -0.11077608809648665]  [0.1952, -0.42333825701624817]
# 9    [0.7919, 0.27746410711405073]   [0.2094, 0.09633507853403141]
#
#                         basic_eps                 capital_reserve  \
# 0    [0.094, -0.7131522734208117]    [0.0223, 0.7559055118110237]
# 1     [0.05, -0.7826086956521738]    [0.0191, 0.5039370078740157]
# 2     [0.02, -0.7973657548125632]  [0.0127, -0.16447368421052636]
# 3     [0.4, -0.18367346938775503]  [0.0127, -0.16447368421052636]
# 4  [0.3277, 0.024062499999999952]  [0.0127, -0.15333333333333335]
# 5    [0.23, -0.20689655172413784]   [0.0127, -0.3923444976076555]
# 6  [0.0987, -0.22099447513812162]   [0.0152, -0.1363636363636364]
# 7   [0.49, -0.057692307692307744]  [0.0152, -0.27272727272727265]
# 8    [0.32, -0.13513513513513511]   [0.015, -0.23857868020304568]
# 9     [0.29, -0.3555555555555556]  [0.0209, 0.060913705583756333]
#
#                undistri_profit_ps     net_interest_of_total_assets  \
# 0   [0.9618, 0.06370272063702719]    [7.2395, -0.7426879591684409]
# 1   [0.9221, 0.14603529704200852]    [4.0687, -0.7985772136357786]
# 2   [0.9907, 0.11239613743543687]     [1.7824, -0.767780600612338]
# 3   [0.9702, 0.22515469124889492]  [33.5042, -0.22362570009755603]
# 4    [0.9042, 0.4481101857783473]  [28.1351, -0.10744276201624894]
# 5   [0.8046, 0.12405699916177702]   [20.1998, 0.06631263329039885]
# 6  [0.8906, -0.07287112221528218]   [7.6755, -0.12957439811297208]
# 7  [0.7919, -0.05036575128912331]   [43.1547, 0.19488153548397802]
# 8  [0.6244, -0.09989909182643798]    [31.5219, 0.1289674438594606]
# 9   [0.7158, 0.29885683179096345]   [18.9436, 0.06507292170334299]
#
#                  gross_selling_rate
# 0    [44.0507, -0.3637987758556446]
# 1   [42.0125, -0.41499234842714566]
# 2    [36.5417, -0.4699461557653366]
# 3   [66.2127, -0.08954316758955348]
# 4  [69.2402, -0.042102277836574074]
# 5   [71.8153, 0.014222928982801345]
# 6   [68.9396, 0.019834671621389754]
# 7    [72.7247, 0.03244935334118891]
# 8     [72.2835, 0.0312719355814392]
# 9   [70.8082, 0.018657398149653275]
